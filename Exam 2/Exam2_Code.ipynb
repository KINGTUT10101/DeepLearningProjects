# %% [markdown]
# # Project Setup

# %% [markdown]
# The following section installs the TensorFlow library for Python.

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %% [markdown]
# This section imports and sets up the needed libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
import numpy as np
import logging

tf.get_logger().setLevel(logging.ERROR)
tf.random.set_seed(42)

# %% [markdown]
# # Question 3

# %% [markdown]
# First, we will load the MNIST dataset, which contains 28x28 grayscale handwritten digits ranging from 0 to 9.

# %%
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Next, we will apply dataset preprocessing to the data. In this case, we will standardize the input images and one-hot encode the labels for multi-class prediction.

# %%
mean = np.mean (train_images)
std = np.std (train_images)
train_images = (train_images - mean) / std
test_images = (test_images - mean) / std

train_labels = to_categorical (train_labels, num_classes=10)
test_labels = to_categorical (test_labels, num_classes=10)

# %% [markdown]
# Now we will define the model's structure. It has one hidden layer with 50 neurons, a batch normalization layer, and a hidden layer with 10 neurons (one for each digit).

# %%
init_config_hidden_q3 = keras.initializers.RandomUniform (minval=-0.1, maxval=0.1)
init_config_output_q3 = keras.initializers.RandomUniform (minval=-0.1, maxval=0.1)

model_q3 = keras.Sequential([
    keras.layers.Flatten (input_shape=(28, 28)),
    keras.layers.Dense (50, activation='tanh', kernel_initializer=init_config_hidden_q3, bias_initializer = 'zeros'),
    keras.layers.BatchNormalization (),
    keras.layers.Dense (10, activation='sigmoid', kernel_initializer=init_config_output_q3, bias_initializer = 'zeros')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Finally, we will train the model and assess its performance.

# %%
batch_size_q3 = 2
epochs_q3 = 10

opt_config_q3 = keras.optimizers.SGD (learning_rate=0.01)
model_q3.compile (optimizer=opt_config_q3, loss='mean_squared_error', metrics=['accuracy'])

history_q3 = model_q3.fit (train_images, train_labels, epochs=epochs_q3, batch_size=batch_size_q3, validation_data=(test_images, test_labels), verbose = 2, shuffle=True)
# Out:
# Epoch 1/10
# 30000/30000 - 51s - 2ms/step - accuracy: 0.5709 - loss: 0.0821 - val_accuracy: 0.8273 - val_loss: 0.0398
# Epoch 2/10
# 30000/30000 - 51s - 2ms/step - accuracy: 0.7099 - loss: 0.0472 - val_accuracy: 0.8526 - val_loss: 0.0382
# Epoch 3/10
# 30000/30000 - 51s - 2ms/step - accuracy: 0.7617 - loss: 0.0387 - val_accuracy: 0.8648 - val_loss: 0.0384
# Epoch 4/10
# 30000/30000 - 51s - 2ms/step - accuracy: 0.7941 - loss: 0.0335 - val_accuracy: 0.8720 - val_loss: 0.0370
# Epoch 5/10
# 30000/30000 - 51s - 2ms/step - accuracy: 0.8132 - loss: 0.0300 - val_accuracy: 0.8759 - val_loss: 0.0368
# Epoch 6/10
# 30000/30000 - 52s - 2ms/step - accuracy: 0.8267 - loss: 0.0276 - val_accuracy: 0.8829 - val_loss: 0.0348
# Epoch 7/10
# 30000/30000 - 50s - 2ms/step - accuracy: 0.8365 - loss: 0.0258 - val_accuracy: 0.8797 - val_loss: 0.0350
# Epoch 8/10
# 30000/30000 - 50s - 2ms/step - accuracy: 0.8441 - loss: 0.0245 - val_accuracy: 0.8820 - val_loss: 0.0332
# Epoch 9/10
# 30000/30000 - 50s - 2ms/step - accuracy: 0.8503 - loss: 0.0233 - val_accuracy: 0.8835 - val_loss: 0.0328
# Epoch 10/10
# 30000/30000 - 50s - 2ms/step - accuracy: 0.8553 - loss: 0.0224 - val_accuracy: 0.8859 - val_loss: 0.0316

# %%
model_q3.summary ()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │        39,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 50)             │           200 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           510 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 39,962 (156.11 KB)
#  Trainable params: 39,860 (155.70 KB)
#  Non-trainable params: 100 (400.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# # Question 4

# %% [markdown]
# We will begin by loading the CIFAR-10 dataset, which contains 32x32 RGB images of various things. As the name suggests, the dataset has 10 unique labels.

# %%
cifar_dataset = keras.datasets.cifar10
(train_images, train_labels), (test_images, test_labels) = cifar_dataset.load_data ()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# Next we will standardize the images and one-hot encode the labels.

# %%
mean = np.mean (train_images)
stddev = np.std (train_images)
train_images = (train_images - mean) / stddev
test_images = (test_images - mean) / stddev

train_labels = to_categorical (train_labels, num_classes=10)
test_labels = to_categorical (test_labels, num_classes=10)

# %% [markdown]
# Now we will define the model. It should have three convolutional layers, and the first two layers should each be followed by max pooling and dropout layers. Then the model should flatten into a dense network with one hidden layer containing 1024 neurons and an output layer with 10 neurons.

# %%
model_q4 = keras.Sequential([
    # Model input
    keras.layers.Input(shape=(32,32,3)),

    # Convolutional part of the model
    keras.layers.Conv2D(64, (5,5), strides=(2,2), padding='same', activation='relu', kernel_initializer='he_normal', bias_initializer='zeros'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    keras.layers.Dropout(0.20),

    keras.layers.Conv2D(64, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer='he_normal', bias_initializer='zeros'),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
    keras.layers.Dropout(0.20),

    keras.layers.Conv2D(64, (3,3), strides=(2,2), padding='same', activation='relu', kernel_initializer='he_normal', bias_initializer='zeros'),

    # Fully connected part of the model
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu', kernel_initializer='he_normal'),
    keras.layers.Dense(10, activation='softmax', kernel_initializer='glorot_uniform', bias_initializer = 'zeros')
])

# %% [markdown]
# Now that the model is defined, let's move on to training.

# %%
batch_size_q4 = 32
epochs_q4 = 128

model_q4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history_q4 = model_q4.fit(train_images, train_labels, validation_data = (test_images, test_labels), epochs=epochs_q4, batch_size=epochs_q4, verbose=2, shuffle=True)
# Out:
# Epoch 1/128
# 391/391 - 13s - 34ms/step - accuracy: 0.3463 - loss: 1.7667 - val_accuracy: 0.4566 - val_loss: 1.5033
# Epoch 2/128
# 391/391 - 2s - 4ms/step - accuracy: 0.4626 - loss: 1.4695 - val_accuracy: 0.5139 - val_loss: 1.3498
# Epoch 3/128
# 391/391 - 3s - 6ms/step - accuracy: 0.5157 - loss: 1.3442 - val_accuracy: 0.5589 - val_loss: 1.2323
# Epoch 4/128
# 391/391 - 2s - 6ms/step - accuracy: 0.5479 - loss: 1.2535 - val_accuracy: 0.5906 - val_loss: 1.1468
# Epoch 5/128
# 391/391 - 3s - 7ms/step - accuracy: 0.5770 - loss: 1.1793 - val_accuracy: 0.6157 - val_loss: 1.0798
# Epoch 6/128
# 391/391 - 2s - 6ms/step - accuracy: 0.5956 - loss: 1.1246 - val_accuracy: 0.6288 - val_loss: 1.0450
# Epoch 7/128
# 391/391 - 2s - 6ms/step - accuracy: 0.6118 - loss: 1.0848 - val_accuracy: 0.6436 - val_loss: 1.0172
# Epoch 8/128
# 391/391 - 2s - 6ms/step - accuracy: 0.6285 - loss: 1.0388 - val_accuracy: 0.6496 - val_loss: 0.9946
# Epoch 9/128
# 391/391 - 2s - 4ms/step - accuracy: 0.6377 - loss: 1.0121 - val_accuracy: 0.6561 - val_loss: 0.9744
# Epoch 10/128
# 391/391 - 2s - 4ms/step - accuracy: 0.6515 - loss: 0.9847 - val_accuracy: 0.6620 - val_loss: 0.9697
# Epoch 11/128
# 391/391 - 2s - 5ms/step - accuracy: 0.6568 - loss: 0.9609 - val_accuracy: 0.6671 - val_loss: 0.9499
# Epoch 12/128
# 391/391 - 2s - 4ms/step - accuracy: 0.6640 - loss: 0.9399 - val_accuracy: 0.6729 - val_loss: 0.9304
# Epoch 13/128
# 391/391 - 3s - 7ms/step - accuracy: 0.6715 - loss: 0.9196 - val_accuracy: 0.6790 - val_loss: 0.9190
# Epoch 14/128
# 391/391 - 2s - 6ms/step - accuracy: 0.6794 - loss: 0.9011 - val_accuracy: 0.6790 - val_loss: 0.9140
# Epoch 15/128
# 391/391 - 2s - 4ms/step - accuracy: 0.6840 - loss: 0.8842 - val_accuracy: 0.6888 - val_loss: 0.8895
# Epoch 16/128
# 391/391 - 2s - 4ms/step - accuracy: 0.6850 - loss: 0.8775 - val_accuracy: 0.6906 - val_loss: 0.8903
# Epoch 17/128
# 391/391 - 2s - 6ms/step - accuracy: 0.6959 - loss: 0.8544 - val_accuracy: 0.6921 - val_loss: 0.8817
# Epoch 18/128
# 391/391 - 2s - 4ms/step - accuracy: 0.6949 - loss: 0.8515 - val_accuracy: 0.6926 - val_loss: 0.8827
# Epoch 19/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7009 - loss: 0.8356 - val_accuracy: 0.6921 - val_loss: 0.8832
# Epoch 20/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7077 - loss: 0.8213 - val_accuracy: 0.6915 - val_loss: 0.8960
# Epoch 21/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7047 - loss: 0.8202 - val_accuracy: 0.6961 - val_loss: 0.8797
# Epoch 22/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7109 - loss: 0.8046 - val_accuracy: 0.6855 - val_loss: 0.8957
# Epoch 23/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7109 - loss: 0.7971 - val_accuracy: 0.6920 - val_loss: 0.8825
# Epoch 24/128
# 391/391 - 2s - 6ms/step - accuracy: 0.7174 - loss: 0.7892 - val_accuracy: 0.6963 - val_loss: 0.8678
# Epoch 25/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7208 - loss: 0.7765 - val_accuracy: 0.7041 - val_loss: 0.8618
# Epoch 26/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7268 - loss: 0.7703 - val_accuracy: 0.6987 - val_loss: 0.8806
# Epoch 27/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7256 - loss: 0.7627 - val_accuracy: 0.6966 - val_loss: 0.8843
# Epoch 28/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7246 - loss: 0.7659 - val_accuracy: 0.6989 - val_loss: 0.8762
# Epoch 29/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7268 - loss: 0.7552 - val_accuracy: 0.6952 - val_loss: 0.8829
# Epoch 30/128
# 391/391 - 3s - 6ms/step - accuracy: 0.7333 - loss: 0.7462 - val_accuracy: 0.6985 - val_loss: 0.8721
# Epoch 31/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7346 - loss: 0.7429 - val_accuracy: 0.6989 - val_loss: 0.8701
# Epoch 32/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7355 - loss: 0.7340 - val_accuracy: 0.6983 - val_loss: 0.8806
# Epoch 33/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7399 - loss: 0.7269 - val_accuracy: 0.6993 - val_loss: 0.8908
# Epoch 34/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7423 - loss: 0.7173 - val_accuracy: 0.7012 - val_loss: 0.8837
# Epoch 35/128
# 391/391 - 3s - 8ms/step - accuracy: 0.7403 - loss: 0.7225 - val_accuracy: 0.6988 - val_loss: 0.8810
# Epoch 36/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7425 - loss: 0.7158 - val_accuracy: 0.7058 - val_loss: 0.8672
# Epoch 37/128
# 391/391 - 3s - 6ms/step - accuracy: 0.7450 - loss: 0.7079 - val_accuracy: 0.7038 - val_loss: 0.8809
# Epoch 38/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7476 - loss: 0.7048 - val_accuracy: 0.7017 - val_loss: 0.8785
# Epoch 39/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7483 - loss: 0.7009 - val_accuracy: 0.6946 - val_loss: 0.8923
# Epoch 40/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7489 - loss: 0.6918 - val_accuracy: 0.7014 - val_loss: 0.8775
# Epoch 41/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7513 - loss: 0.6880 - val_accuracy: 0.7065 - val_loss: 0.8648
# Epoch 42/128
# 391/391 - 2s - 5ms/step - accuracy: 0.7527 - loss: 0.6861 - val_accuracy: 0.7043 - val_loss: 0.8616
# Epoch 43/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7530 - loss: 0.6836 - val_accuracy: 0.7040 - val_loss: 0.8845
# Epoch 44/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7547 - loss: 0.6803 - val_accuracy: 0.7007 - val_loss: 0.8886
# Epoch 45/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7567 - loss: 0.6776 - val_accuracy: 0.7037 - val_loss: 0.8738
# Epoch 46/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7562 - loss: 0.6743 - val_accuracy: 0.6996 - val_loss: 0.8924
# Epoch 47/128
# 391/391 - 3s - 6ms/step - accuracy: 0.7605 - loss: 0.6673 - val_accuracy: 0.7053 - val_loss: 0.8828
# Epoch 48/128
# 391/391 - 2s - 5ms/step - accuracy: 0.7603 - loss: 0.6637 - val_accuracy: 0.7063 - val_loss: 0.8902
# Epoch 49/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7645 - loss: 0.6565 - val_accuracy: 0.7079 - val_loss: 0.8782
# Epoch 50/128
# 391/391 - 3s - 6ms/step - accuracy: 0.7644 - loss: 0.6568 - val_accuracy: 0.7101 - val_loss: 0.8713
# Epoch 51/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7627 - loss: 0.6590 - val_accuracy: 0.7025 - val_loss: 0.8819
# Epoch 52/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7665 - loss: 0.6522 - val_accuracy: 0.7077 - val_loss: 0.8652
# Epoch 53/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7657 - loss: 0.6483 - val_accuracy: 0.7041 - val_loss: 0.8840
# Epoch 54/128
# 391/391 - 3s - 8ms/step - accuracy: 0.7681 - loss: 0.6433 - val_accuracy: 0.7061 - val_loss: 0.8775
# Epoch 55/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7706 - loss: 0.6400 - val_accuracy: 0.7074 - val_loss: 0.8817
# Epoch 56/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7703 - loss: 0.6424 - val_accuracy: 0.6995 - val_loss: 0.8951
# Epoch 57/128
# 391/391 - 2s - 6ms/step - accuracy: 0.7710 - loss: 0.6350 - val_accuracy: 0.7035 - val_loss: 0.8897
# Epoch 58/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7703 - loss: 0.6359 - val_accuracy: 0.7020 - val_loss: 0.8850
# Epoch 59/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7731 - loss: 0.6300 - val_accuracy: 0.7130 - val_loss: 0.8809
# Epoch 60/128
# 391/391 - 2s - 5ms/step - accuracy: 0.7747 - loss: 0.6288 - val_accuracy: 0.7055 - val_loss: 0.8818
# Epoch 61/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7743 - loss: 0.6269 - val_accuracy: 0.7065 - val_loss: 0.8794
# Epoch 62/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7753 - loss: 0.6221 - val_accuracy: 0.7069 - val_loss: 0.8959
# Epoch 63/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7741 - loss: 0.6262 - val_accuracy: 0.7054 - val_loss: 0.8986
# Epoch 64/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7773 - loss: 0.6215 - val_accuracy: 0.7028 - val_loss: 0.9048
# Epoch 65/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7774 - loss: 0.6174 - val_accuracy: 0.7042 - val_loss: 0.8988
# Epoch 66/128
# 391/391 - 2s - 5ms/step - accuracy: 0.7774 - loss: 0.6176 - val_accuracy: 0.6955 - val_loss: 0.9201
# Epoch 67/128
# 391/391 - 2s - 6ms/step - accuracy: 0.7758 - loss: 0.6153 - val_accuracy: 0.7057 - val_loss: 0.9022
# Epoch 68/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7808 - loss: 0.6122 - val_accuracy: 0.7058 - val_loss: 0.9126
# Epoch 69/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7793 - loss: 0.6169 - val_accuracy: 0.7062 - val_loss: 0.8914
# Epoch 70/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7797 - loss: 0.6110 - val_accuracy: 0.7052 - val_loss: 0.8771
# Epoch 71/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7840 - loss: 0.6031 - val_accuracy: 0.7013 - val_loss: 0.9153
# Epoch 72/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7841 - loss: 0.6030 - val_accuracy: 0.7024 - val_loss: 0.9043
# Epoch 73/128
# 391/391 - 2s - 6ms/step - accuracy: 0.7828 - loss: 0.6006 - val_accuracy: 0.7046 - val_loss: 0.9063
# Epoch 74/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7818 - loss: 0.6032 - val_accuracy: 0.7115 - val_loss: 0.8983
# Epoch 75/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7839 - loss: 0.6022 - val_accuracy: 0.7022 - val_loss: 0.9161
# Epoch 76/128
# 391/391 - 2s - 6ms/step - accuracy: 0.7844 - loss: 0.5967 - val_accuracy: 0.7046 - val_loss: 0.9040
# Epoch 77/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7841 - loss: 0.5981 - val_accuracy: 0.7063 - val_loss: 0.9113
# Epoch 78/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7861 - loss: 0.5977 - val_accuracy: 0.7040 - val_loss: 0.9140
# Epoch 79/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7893 - loss: 0.5911 - val_accuracy: 0.7118 - val_loss: 0.8941
# Epoch 80/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7856 - loss: 0.5884 - val_accuracy: 0.7097 - val_loss: 0.8925
# Epoch 81/128
# 391/391 - 2s - 6ms/step - accuracy: 0.7836 - loss: 0.5984 - val_accuracy: 0.7091 - val_loss: 0.9066
# Epoch 82/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7900 - loss: 0.5832 - val_accuracy: 0.7104 - val_loss: 0.9013
# Epoch 83/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7876 - loss: 0.5914 - val_accuracy: 0.7123 - val_loss: 0.8912
# Epoch 84/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7918 - loss: 0.5797 - val_accuracy: 0.7130 - val_loss: 0.9018
# Epoch 85/128
# 391/391 - 2s - 6ms/step - accuracy: 0.7903 - loss: 0.5821 - val_accuracy: 0.7113 - val_loss: 0.9128
# Epoch 86/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7924 - loss: 0.5766 - val_accuracy: 0.7131 - val_loss: 0.8942
# Epoch 87/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7893 - loss: 0.5792 - val_accuracy: 0.7108 - val_loss: 0.9010
# Epoch 88/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7990 - loss: 0.5653 - val_accuracy: 0.7117 - val_loss: 0.9154
# Epoch 89/128
# 391/391 - 3s - 8ms/step - accuracy: 0.7915 - loss: 0.5812 - val_accuracy: 0.7066 - val_loss: 0.9165
# Epoch 90/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7917 - loss: 0.5799 - val_accuracy: 0.7065 - val_loss: 0.9200
# Epoch 91/128
# 391/391 - 3s - 6ms/step - accuracy: 0.7926 - loss: 0.5753 - val_accuracy: 0.7085 - val_loss: 0.9175
# Epoch 92/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7960 - loss: 0.5644 - val_accuracy: 0.7107 - val_loss: 0.9153
# Epoch 93/128
# 391/391 - 2s - 6ms/step - accuracy: 0.7960 - loss: 0.5692 - val_accuracy: 0.7131 - val_loss: 0.9229
# Epoch 94/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7940 - loss: 0.5681 - val_accuracy: 0.7094 - val_loss: 0.9267
# Epoch 95/128
# 391/391 - 2s - 5ms/step - accuracy: 0.7958 - loss: 0.5635 - val_accuracy: 0.7093 - val_loss: 0.9216
# Epoch 96/128
# 391/391 - 2s - 6ms/step - accuracy: 0.7963 - loss: 0.5687 - val_accuracy: 0.7099 - val_loss: 0.9036
# Epoch 97/128
# 391/391 - 3s - 6ms/step - accuracy: 0.7955 - loss: 0.5662 - val_accuracy: 0.7042 - val_loss: 0.9218
# Epoch 98/128
# 391/391 - 2s - 4ms/step - accuracy: 0.8002 - loss: 0.5586 - val_accuracy: 0.7104 - val_loss: 0.9142
# Epoch 99/128
# 391/391 - 2s - 6ms/step - accuracy: 0.8000 - loss: 0.5583 - val_accuracy: 0.7087 - val_loss: 0.9255
# Epoch 100/128
# 391/391 - 2s - 5ms/step - accuracy: 0.7983 - loss: 0.5586 - val_accuracy: 0.7019 - val_loss: 0.9364
# Epoch 101/128
# 391/391 - 2s - 6ms/step - accuracy: 0.7979 - loss: 0.5592 - val_accuracy: 0.7086 - val_loss: 0.9395
# Epoch 102/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7986 - loss: 0.5584 - val_accuracy: 0.7085 - val_loss: 0.9386
# Epoch 103/128
# 391/391 - 2s - 4ms/step - accuracy: 0.7991 - loss: 0.5584 - val_accuracy: 0.7061 - val_loss: 0.9402
# Epoch 104/128
# 391/391 - 3s - 7ms/step - accuracy: 0.7988 - loss: 0.5599 - val_accuracy: 0.7115 - val_loss: 0.9277
# Epoch 105/128
# 391/391 - 3s - 7ms/step - accuracy: 0.8005 - loss: 0.5543 - val_accuracy: 0.7094 - val_loss: 0.9319
# Epoch 106/128
# 391/391 - 2s - 5ms/step - accuracy: 0.8009 - loss: 0.5554 - val_accuracy: 0.7066 - val_loss: 0.9246
# Epoch 107/128
# 391/391 - 2s - 4ms/step - accuracy: 0.8004 - loss: 0.5558 - val_accuracy: 0.7074 - val_loss: 0.9385
# Epoch 108/128
# 391/391 - 3s - 7ms/step - accuracy: 0.8027 - loss: 0.5502 - val_accuracy: 0.7137 - val_loss: 0.9085
# Epoch 109/128
# 391/391 - 3s - 7ms/step - accuracy: 0.8023 - loss: 0.5500 - val_accuracy: 0.7118 - val_loss: 0.9183
# Epoch 110/128
# 391/391 - 2s - 4ms/step - accuracy: 0.8034 - loss: 0.5516 - val_accuracy: 0.7148 - val_loss: 0.9291
# Epoch 111/128
# 391/391 - 2s - 4ms/step - accuracy: 0.8033 - loss: 0.5433 - val_accuracy: 0.7162 - val_loss: 0.9344
# Epoch 112/128
# 391/391 - 3s - 7ms/step - accuracy: 0.8032 - loss: 0.5454 - val_accuracy: 0.7084 - val_loss: 0.9426
# Epoch 113/128
# 391/391 - 2s - 4ms/step - accuracy: 0.8029 - loss: 0.5504 - val_accuracy: 0.7133 - val_loss: 0.9214
# Epoch 114/128
# 391/391 - 2s - 4ms/step - accuracy: 0.8051 - loss: 0.5404 - val_accuracy: 0.7128 - val_loss: 0.9317
# Epoch 115/128
# 391/391 - 3s - 7ms/step - accuracy: 0.8042 - loss: 0.5428 - val_accuracy: 0.7145 - val_loss: 0.9307
# Epoch 116/128
# 391/391 - 3s - 6ms/step - accuracy: 0.8053 - loss: 0.5419 - val_accuracy: 0.7095 - val_loss: 0.9266
# Epoch 117/128
# 391/391 - 2s - 4ms/step - accuracy: 0.8045 - loss: 0.5418 - val_accuracy: 0.7177 - val_loss: 0.9142
# Epoch 118/128
# 391/391 - 3s - 6ms/step - accuracy: 0.8070 - loss: 0.5414 - val_accuracy: 0.7072 - val_loss: 0.9354
# Epoch 119/128
# 391/391 - 2s - 6ms/step - accuracy: 0.8061 - loss: 0.5444 - val_accuracy: 0.7149 - val_loss: 0.9231
# Epoch 120/128
# 391/391 - 2s - 4ms/step - accuracy: 0.8064 - loss: 0.5404 - val_accuracy: 0.7146 - val_loss: 0.9308
# Epoch 121/128
# 391/391 - 2s - 6ms/step - accuracy: 0.8096 - loss: 0.5332 - val_accuracy: 0.7122 - val_loss: 0.9195
# Epoch 122/128
# 391/391 - 3s - 7ms/step - accuracy: 0.8085 - loss: 0.5341 - val_accuracy: 0.7110 - val_loss: 0.9356
# Epoch 123/128
# 391/391 - 2s - 4ms/step - accuracy: 0.8074 - loss: 0.5381 - val_accuracy: 0.7092 - val_loss: 0.9489
# Epoch 124/128
# 391/391 - 2s - 6ms/step - accuracy: 0.8043 - loss: 0.5401 - val_accuracy: 0.7116 - val_loss: 0.9364
# Epoch 125/128
# 391/391 - 3s - 7ms/step - accuracy: 0.8097 - loss: 0.5370 - val_accuracy: 0.7153 - val_loss: 0.9357
# Epoch 126/128
# 391/391 - 2s - 4ms/step - accuracy: 0.8121 - loss: 0.5255 - val_accuracy: 0.7139 - val_loss: 0.9317
# Epoch 127/128
# 391/391 - 2s - 6ms/step - accuracy: 0.8086 - loss: 0.5282 - val_accuracy: 0.7102 - val_loss: 0.9503
# Epoch 128/128
# 391/391 - 2s - 5ms/step - accuracy: 0.8080 - loss: 0.5315 - val_accuracy: 0.7076 - val_loss: 0.9386

# %%
model_q4.summary ()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 16, 16, 64)     │         4,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 1, 1, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 466,592 (1.78 MB)
#  Trainable params: 155,530 (607.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 311,062 (1.19 MB)
